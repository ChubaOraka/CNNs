# %% [markdown]
# STEP 1
# Define the Imports.
# Notice that we have put the RandomNo seed, lines right at the top, We want them to be always constant, so that we get similar results whenever we RE run the notebook.

# %%
from numpy.random import seed
seed(1)
import tensorflow as tf
tf.set_random_seed(1)

import numpy as np
import scipy
import h5py
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.python.keras.optimizers import Adam,RMSprop 
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras.preprocessing import image
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Activation, Flatten, Dense,Conv2D, MaxPooling2D,Dropout,BatchNormalization, PReLU,LeakyReLU
from tensorflow.python.keras import backend as K
from tensorflow.python.keras.callbacks import TensorBoard,ModelCheckpoint,ReduceLROnPlateau
from tensorflow.python.keras.wrappers.scikit_learn import KerasClassifier

# %% [markdown]
# STEP 2
# Define the Data Source.
# This may differ, and you should modify it to point to your correct paths

# %%
STARTDIR='C:\\data\\ourclothdata\\'
train_data_dir = STARTDIR+'train'
validation_data_dir = STARTDIR+'validation'
userCreatedImages_dir = STARTDIR+'UserData\\'
model_dir = STARTDIR+'model_ourclothes.json'
weights_dir= STARTDIR+'model_ourclothes.h5'

# %% [markdown]
# ###### STEP 3
# Initalize the Variables.
# a) Size of the image ( remember its always square, our images are 60x60 pixels)
# b) Number of images in Training and Validation directories.
# c) EPOCHS (How many times do you want to repeat the training)
# d) BATCHES: What size batch do we want to divide our Data
# e) num_classes:  how many output labels are there   ( we have 10 unique digits)

# %%
# Initialize the variables
image_width, image_height = 32, 32
nb_train_samples = 773
nb_validation_samples = 147
epochs =30
batch_size = 60
num_classes=6

# %% [markdown]
# STEP 4
# Pull the images from the directories.
# As we get an image, we are doing multiple things here
# a) we are dividing it by 255 ( normalization)
# b) we are automatically resizing the image to our required image_width and image_height
# c) we are pulling the defined batch quantity of images.
# Note the use of class_mode = "categorical"  , this pulls the subdir names as labels

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./ 255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(image_width, image_height),
    batch_size=batch_size,
    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(image_width, image_height),
    batch_size=batch_size,
    class_mode='categorical')
print(train_generator.class_indices.keys())
# Out:
# Found 773 images belonging to 6 classes.
# Found 147 images belonging to 6 classes.
# dict_keys(['hat', 'pant', 'shirt', 'shoes', 'skirt', 'socks'])

# %% [markdown]
# STEP 5
# Here we define the Model
# This is a deep network.
# We are using Dropout , to avoid overfitting issues.
# Note that the loss is "categorical_crossentropy"

# %%
optimizer = RMSprop(lr=0.001,decay=1e-6)

model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(image_width, image_height, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3,3)  ))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(96, (3, 3) ))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(1024,   activation='relu'))

model.add(Dense(num_classes,   activation='softmax'))
model.compile(loss='categorical_crossentropy',
#              optimizer='Adam',             
              optimizer=optimizer,
              metrics=['accuracy'])
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 30, 30, 32)        896
# _________________________________________________________________
# activation_13 (Activation)   (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 13, 13, 64)        18496
# _________________________________________________________________
# activation_14 (Activation)   (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 4, 4, 96)          55392
# _________________________________________________________________
# activation_15 (Activation)   (None, 4, 4, 96)          0
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 2, 2, 96)          0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 2, 2, 96)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 384)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1024)              394240
# _________________________________________________________________
# dense_10 (Dense)             (None, 6)                 6150
# =================================================================
# Total params: 475,174
# Trainable params: 475,174
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# STEP 6
# We run the model, training it, with the given data.
# We collect a trace of its values after every run, in history.
# we save the last model

# %%
checkpointer = ModelCheckpoint(filepath=weights_dir,
                               verbose=1, 
                               monitor='val_acc',
                               save_best_only=True,
                               mode='max')
tensorBoardPointer = TensorBoard(log_dir='C:\\data\\ourclothdata\\logs', histogram_freq=0, write_graph=True, write_images=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001)
with tf.device('/gpu:0'):
    history=model.fit_generator(
        train_generator,
        steps_per_epoch=nb_train_samples // batch_size,
        epochs=epochs,
        validation_data=validation_generator,
        validation_steps=nb_validation_samples,
        callbacks=[checkpointer ,tensorBoardPointer,reduce_lr ])
# Out:
# Epoch 1/30
# 11/12 [==========================>...] - ETA: 0s - loss: 1.8331 - acc: 0.1886
# Epoch 00001: val_acc improved from -inf to 0.17007, saving model to C:\data\ourclothdata\model_ourclothes.h5
# 12/12 [==============================] - 12s 1s/step - loss: 1.8284 - acc: 0.1909 - val_loss: 1.7878 - val_acc: 0.1701
# Epoch 2/30
# 11/12 [==========================>...] - ETA: 0s - loss: 1.7288 - acc: 0.2606
# Epoch 00002: val_acc improved from 0.17007 to 0.32653, saving model to C:\data\ourclothdata\model_ourclothes.h5
# 12/12 [==============================] - 12s 978ms/step - loss: 1.7190 - acc: 0.2611 - val_loss: 1.6590 - val_acc: 0.3265
# Epoch 3/30
# 11/12 [==========================>...] - ETA: 0s - loss: 1.5229 - acc: 0.3883
# Epoch 00003: val_acc improved from 0.32653 to 0.40816, saving model to C:\data\ourclothdata\model_ourclothes.h5
# 12/12 [==============================] - 12s 976ms/step - loss: 1.5103 - acc: 0.3990 - val_loss: 1.4953 - val_acc: 0.4082
# Epoch 4/30
# 11/12 [==========================>...] - ETA: 0s - loss: 1.2894 - acc: 0.5181
# Epoch 00004: val_acc improved from 0.40816 to 0.44218, saving model to C:\data\ourclothdata\model_ourclothes.h5
# 12/12 [==============================] - 12s 967ms/step - loss: 1.2807 - acc: 0.5096 - val_loss: 1.4272 - val_acc: 0.4422
# Epoch 5/30
# 11/12 [==========================>...] - ETA: 0s - loss: 1.0945 - acc: 0.5848
# Epoch 00005: val_acc improved from 0.44218 to 0.53061, saving model to C:\data\ourclothdata\model_ourclothes.h5
# 12/12 [==============================] - 11s 957ms/step - loss: 1.1065 - acc: 0.5778 - val_loss: 1.2764 - val_acc: 0.5306
# Epoch 6/30
# 11/12 [==========================>...] - ETA: 0s - loss: 1.0111 - acc: 0.6063
# Epoch 00006: val_acc did not improve
# 12/12 [==============================] - 11s 935ms/step - loss: 1.0071 - acc: 0.6058 - val_loss: 1.4202 - val_acc: 0.4694
# Epoch 7/30
# 11/12 [==========================>...] - ETA: 0s - loss: 0.9387 - acc: 0.6470
# Epoch 00007: val_acc did not improve
# 12/12 [==============================] - 11s 947ms/step - loss: 0.9691 - acc: 0.6389 - val_loss: 1.2769 - val_acc: 0.4966
# Epoch 8/30
# 11/12 [==========================>...] - ETA: 0s - loss: 0.8719 - acc: 0.6756
# Epoch 00008: val_acc improved from 0.53061 to 0.61905, saving model to C:\data\ourclothdata\model_ourclothes.h5
# 12/12 [==============================] - 11s 940ms/step - loss: 0.8590 - acc: 0.6820 - val_loss: 1.0579 - val_acc: 0.6190
# Epoch 9/30
# 11/12 [==========================>...] - ETA: 0s - loss: 0.7509 - acc: 0.7318
# Epoch 00009: val_acc improved from 0.61905 to 0.64626, saving model to C:\data\ourclothdata\model_ourclothes.h5
# 12/12 [==============================] - 11s 918ms/step - loss: 0.7462 - acc: 0.7319 - val_loss: 1.0096 - val_acc: 0.6463
# Epoch 10/30
# 11/12 [==========================>...] - ETA: 0s - loss: 0.7667 - acc: 0.7432
# Epoch 00010: val_acc did not improve
# 12/12 [==============================] - 11s 910ms/step - loss: 0.7623 - acc: 0.7438 - val_loss: 1.2172 - val_acc: 0.5238
# Epoch 11/30
# 11/12 [==========================>...] - ETA: 0s - loss: 0.7761 - acc: 0.7078
# Epoch 00011: val_acc improved from 0.64626 to 0.68027, saving model to C:\data\ourclothdata\model_ourclothes.h5
# 12/12 [==============================] -
30
# 11/12 [==========================>...] - ETA: 0s - loss: 0.3463 - acc: 0.8738
# Epoch 00024: val_acc did not improve
# 12/12 [==============================] - 11s 937ms/step - loss: 0.3565 - acc: 0.8704 - val_loss: 0.8984 - val_acc: 0.6735
# Epoch 25/30
#  9/12 [=====================>........] - ETA: 0s - loss: 0.3712 - acc: 0.8542
# Epoch 00025: val_acc improved from 0.70748 to 0.74830, saving model to C:\data\ourclothdata\model_ourclothes.h5
# 12/12 [==============================] - 11s 935ms/step - loss: 0.3841 - acc: 0.8554 - val_loss: 0.7744 - val_acc: 0.7483
# Epoch 26/30
#  9/12 [=====================>........] - ETA: 0s - loss: 0.3379 - acc: 0.8741
# Epoch 00026: val_acc did not improve
# 12/12 [==============================] - 11s 918ms/step - loss: 0.3401 - acc: 0.8764 - val_loss: 0.8113 - val_acc: 0.7279
# Epoch 27/30
#  9/12 [=====================>........] - ETA: 0s - loss: 0.2838 - acc: 0.9019
# Epoch 00027: val_acc did not improve
# 12/12 [==============================] - 11s 910ms/step - loss: 0.2962 - acc: 0.8991 - val_loss: 0.8799 - val_acc: 0.6803
# Epoch 28/30
# 11/12 [==========================>...] - ETA: 0s - loss: 0.3037 - acc: 0.9047
# Epoch 00028: val_acc did not improve
# 12/12 [==============================] - 12s 962ms/step - loss: 0.3171 - acc: 0.8973 - val_loss: 0.9733 - val_acc: 0.6599
# Epoch 29/30
# 11/12 [==========================>...] - ETA: 0s - loss: 0.2312 - acc: 0.9197
# Epoch 00029: val_acc did not improve
# 12/12 [==============================] - 11s 913ms/step - loss: 0.2275 - acc: 0.9217 - val_loss: 0.8510 - val_acc: 0.7347
# Epoch 30/30
# 11/12 [==========================>...] - ETA: 0s - loss: 0.2345 - acc: 0.9318
# Epoch 00030: val_acc did not improve
# 12/12 [==============================] - 11s 886ms/step - loss: 0.2383 - acc: 0.9278 - val_loss: 0.8508 - val_acc: 0.7347

# %%
model_json = model.to_json()
with open(model_dir, "w") as json_file:
    json_file.write(model_json)

model.save_weights(weights_dir)
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'r',linewidth=3.0)
plt.plot(history.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
 
# Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['acc'],'r',linewidth=3.0)
plt.plot(history.history['val_acc'],'b',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16)
# Out:
# Text(0.5,1,'Accuracy Curves')

# %% [markdown]
# Step 7  Here we use the above model, to predict the label of new images, we give it.

# %%
path = userCreatedImages_dir
files = os.listdir(path)
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())

    
for file in files:
    pred=-1
    t_image= image.load_img(path + file )
    test_image = image.load_img(path + file, target_size=(image_height, image_width))
    test_image = image.img_to_array(test_image)
    test_image = np.expand_dims(test_image, axis=0)
 
    predictions = model.predict_classes(test_image)
    a = predictions[0]
    print(labels[a])
    plt.imshow(t_image)
    plt.show()
# Out:
# shirt
# hat
# socks
# hat
# hat
# hat
# hat
# hat
# hat
# hat
# shoes
# skirt
# pant
# pant
# pant
# pant
# pant
# pant
# pant
# pant
# pant
# pant
# pant
# pant
# shirt
# shirt
# shirt
# shirt
# shirt
# shirt
# socks
# shirt
# shoes
# socks
# shoes
# shoes
# shoes
# shoes
# shoes
# shoes
# socks
# shoes
# skirt
# skirt
# skirt
# skirt
# socks
# skirt
# skirt
# skirt
# skirt
# skirt
# skirt
# skirt
# socks
# socks
# socks
# socks
# socks
# socks
# socks
# socks
# skirt
# socks
# socks
# socks
